# %%
import pandas as pd
import numpy as np

df = pd.read_csv('eda/wine.csv')
df['split'] = np.random.randn(df.shape[0], 1)

msk = np.random.rand(len(df)) <= 0.7

train = df[msk]
test = df[~msk]

# %%
len(train)
# Out:
# 89465

# %%
len(test)
# Out:
# 38672

# %%
train.head()
# Out:
#   country                                        description  \
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La B�gude, named aft...
# 5   Spain  Deep, dense and pure from the opening bell, th...
# 7   Spain  Lush cedary black-fruit aromas are luxe and of...
#
#                              designation  points  price        province  \
# 1  Carodorum Selecci�_n Especial Reserva      96  110.0  Northern Spain
# 3                                Reserve      96   65.0          Oregon
# 4                            La Br��lade      95   66.0        Provence
# 5                              Numanthia      95   73.0  Northern Spain
# 7               Carodorum �_nico Crianza      95  110.0  Northern Spain
#
#             region_1           region_2             variety  \
# 1               Toro                NaN       Tinta de Toro
# ...

# %%
train.drop(['split'], axis=1)
# Out:
#             country                                        description  \
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 3                US  This spent 20 months in 30% new French oak, an...
# 4            France  This is the top wine from La B�gude, named aft...
# 5             Spain  Deep, dense and pure from the opening bell, th...
# 7             Spain  Lush cedary black-fruit aromas are luxe and of...
# 9                US  The producer sources from two blocks of the vi...
# 11               US  From 18-year-old vines, this supple well-balan...
# 12               US  A standout even in this terrific lineup of 201...
# 13           France  This wine is in peak condition. The tannins an...
# 14               US  With its sophisticated mix of mineral, acid an...
# 15               US  First made in 2006, this succulent luscious Ch...
# 16               US  This blockbuster, powerhouse of a wine suggest...
# ...

# %%
train.to_csv('eda/wine_train_data.csv')

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('eda/wine_train_data.csv')
df['split'] = np.random.randn(df.shape[0], 1)

msk = np.random.rand(len(df)) <= 0.10

train_sample = df[msk]
train = df[~msk]

# %%
train.drop(['split'], axis=1)
# Out:
#        Unnamed: 0       country  \
# 0               1         Spain
# 1               3            US
# 2               4        France
# 3               5         Spain
# 4               7         Spain
# 5               9            US
# 6              11            US
# 7              12            US
# 8              13        France
# 9              14            US
# 10             15            US
# 11             16            US
# 12             17         Spain
# 13             18        France
# 14             19            US
# 15             20            US
# 16             21         Spain
# 17             25   New Zealand
# 18             26            US
# 19             27            US
# 20             28            US
# 21             30      Bulgaria
# 22             31            US
# 23             33        France
# 25             35         Italy
# 26             37         Italy
# 27             38         Italy
# 28             41         Spain
# ...

# %%
train_sample.drop(['split'], axis=1)
# Out:
#        Unnamed: 0      country  \
# 24             34           US
# 29             42           US
# 33             47           US
# 36             52       France
# 42             59        Italy
# 44             64     Portugal
# 74            110     Portugal
# 81            117       France
# 84            121           US
# 98            141           US
# 110           158        Spain
# 116           165           US
# 123           174       France
# 142           199           US
# 150           208           US
# 172           238     Portugal
# 174           244       France
# 179           251        Italy
# 184           258        Italy
# 189           263           US
# 190           264        Italy
# 194           268           US
# 199           275           US
# 203           283       France
# 221           306           US
# 223           309        Italy
# 246           339           US
# 251           344           US
# 253           346      Germany
# ...

# %%
train_sample.to_csv('eda/train_sample.csv') #smaller training data set to test flow

# %%
# Out:
# 8925
